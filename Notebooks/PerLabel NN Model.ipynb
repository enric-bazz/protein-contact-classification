# %% [markdown]
# # MODEL IMPLEMENTATION
# This notebook presents the implementation and training process of a machine learning model (Neural Network).
#
# In this case, based on the results already obtained from the XGBoost model, we used only the configuration with the data integrated with the new features and without the use of SMOTE.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    classification_report,
    precision_score,
    recall_score,
    accuracy_score,
    f1_score,
    balanced_accuracy_score,
    roc_auc_score,
    matthews_corrcoef,
    confusion_matrix,
    hamming_loss)
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from keras.metrics import AUC, Precision, Recall, F1Score
from tensorflow.keras.models import load_model, clone_model
import joblib

# %%
# Set Pandas to display all columns
pd.set_option('display.max_columns', None)

# %%
DATA_FOLDER = "/content/drive/MyDrive/Structural Bioinfo PROJECT/datasets"
TARGETS = ['HBOND', 'IONIC', 'PICATION', 'PIHBOND', 'PIPISTACK', 'SSBOND', 'VDW']
EXPERIMENT_NAME = "new_no_smote"
TRAIN_FILE = "train_set_new.tsv"
VAL_FILE = "val_set_new.tsv"
TEST_FILE = "test_set_new.tsv"
OUTPUT_FOLDER = os.path.join(DATA_FOLDER, f"results_{EXPERIMENT_NAME}")
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # Data Loading

# %%
def load_tsv_as_df(folder, filename):
    if not filename.endswith('.tsv'):
        filename += '.tsv'
    path = os.path.join(folder, filename)
    df = pd.read_csv(path, sep='\t')
    return df

# %%
def load_dataset(folder, train_file, val_file, test_file, target_cols):
    train_df = load_tsv_as_df(folder, train_file)
    val_df = load_tsv_as_df(folder, val_file)
    test_df = load_tsv_as_df(folder, test_file)
    X_train, y_train = train_df.drop(columns=target_cols), train_df[target_cols]
    X_val, y_val = val_df.drop(columns=target_cols), val_df[target_cols]
    X_test, y_test = test_df.drop(columns=target_cols), test_df[target_cols]
    for df in [X_train, X_val, X_test]:
        df['same_chain'] = df['same_chain'].astype(int)
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset(DATA_FOLDER, TRAIN_FILE, VAL_FILE, TEST_FILE, TARGETS)

# %%
# List of continuous columns
continuous_cols = [
    's_resi', 's_rsa', 's_phi', 's_psi', 's_a1', 's_a2', 's_a3', 's_a4', 's_a5',
    't_resi', 't_rsa', 't_phi', 't_psi', 't_a1', 't_a2', 't_a3', 't_a4', 't_a5',
    'delta_rsa', 'delta_atchley_1', 'delta_atchley_2', 'delta_atchley_3', 'delta_atchley_4', 'delta_atchley_5',
    'ca_distance', 's_centroid_x', 's_centroid_y', 't_centroid_x', 't_centroid_y'
]

# Scale only continuous columns
scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_val_scaled = X_val.copy()
X_test_scaled = X_test.copy()

# Fit scaler only on training data
X_train_scaled[continuous_cols] = scaler.fit_transform(X_train[continuous_cols])
X_val_scaled[continuous_cols] = scaler.transform(X_val[continuous_cols])
X_test_scaled[continuous_cols] = scaler.transform(X_test[continuous_cols])

# Save the scaler
scaler_filename = os.path.join(folder_path, f"{model_name}_scaler.pkl")
joblib.dump(scaler, scaler_filename)
print(f"Scaler saved to: {scaler_filename}")

# %%
def make_dataset(X, y, batch_size=64, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((X.values.astype(np.float32), y.values.astype(np.float32)))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(X))
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

# %%
def compute_class_weights(y_df):
    weights = {}
    for i, col in enumerate(y_df.columns):
        w = compute_class_weight('balanced', classes=np.array([0, 1]), y=y_df[col])
        weights[col] = {0: w[0], 1: w[1]}
    return weights

# %%
class_weights = compute_class_weights(y_train)

# %% [markdown]
# # Neural Network
# This network has three hidden layers, making it deeper than a simple perceptron but not quite a “deep neural network” in the classical sense. Also, here we used a *One-vs-All* approach, and we implemented class weights during training - as for XGBoost model - to handle class imbalance effectively.

# %%
def make_model(input_dim):
    model = models.Sequential([
        layers.Input(shape=(input_dim,)),

        layers.Dense(256),
        layers.BatchNormalization(),
        layers.LeakyReLU(),

        layers.Dense(128),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.Dropout(0.3),

        layers.Dense(64),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy',
                           keras.metrics.AUC(name='auc'),
                           keras.metrics.F1Score(name='f1_score'),
                           keras.metrics.Precision(name='precision'),
                           keras.metrics.Recall(name='recall')
                  ])

    # Implement early stopping
    early_stopping = EarlyStopping(monitor='val_loss',
                                  patience=5,
                                  restore_best_weights=True)
    return model, early_stopping

# %% [markdown]
# # Performance Evaluation Metrics
# In this section, the following metrics are computed for each label:
# * **Accuracy** (both standard and balanced);
#
# * **Precision** (macro version);
#
# * **Recall** (macro version);
#
# * **F1 score** (macro version);
#
# * **MCC** (Matthews Correlation Coefficient);
#
# * **ROC AUC score** (macro version);
#
# * **Confusion matrix**.

# %%
results = {}
for i, target in enumerate(TARGETS):
    print(f"\nTraining model for label: {target}")
    y_train_i, y_val_i, y_test_i = y_train[target], y_val[target], y_test[target]

    model, early_stopping = make_model(X_train_scaled.shape[1])

    # Convert to datasets
    train_ds = make_dataset(X_train_scaled, y_train[[target]], batch_size=64, shuffle=True)
    val_ds = make_dataset(X_val_scaled, y_val[[target]], batch_size=64)
    test_ds = make_dataset(X_test_scaled, y_test[[target]], batch_size=64)

    # Train with class weights
    cw = class_weights[target]
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=20,
        class_weight=cw,
        callbacks=[early_stopping],
        batch_size=64,
        shuffle=True
    )

    # Save model
    model.save(os.path.join(OUTPUT_FOLDER, f"model_{target}.h5"))

    test_loss, test_accuracy, test_auc, test_f1_score, test_precision, test_recall = model.evaluate(test_ds)

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")
    print(f"Test Precision: {test_precision:.4f}")
    print(f"test AUC: {test_auc:.4f}")
    print(f"Test Recall: {test_recall:.4f}")
    print(f"Test F1 Score: {test_f1_score:.4f}")

    y_true = []
    y_pred = []

    for batch_x, batch_y in test_ds:
        preds = model.predict(batch_x, verbose=0)
        y_true.append(batch_y.numpy())
        y_pred.append(preds)

    y_true = np.vstack(y_true)
    y_pred = np.vstack(y_pred)
    y_pred_binary = (y_pred >= 0.5).astype(int)

    # Metrics
    acc = accuracy_score(y_true, y_pred_binary)
    bal_acc = balanced_accuracy_score(y_true, y_pred_binary)
    prec = precision_score(y_true, y_pred_binary, average='macro')
    rec = recall_score(y_true, y_pred_binary, average='macro')
    f1 = f1_score(y_true, y_pred_binary, average='macro')
    auc = roc_auc_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true.ravel(), y_pred_binary.ravel())
    cm = confusion_matrix(y_true, y_pred_binary)

    results[target] = {
        'accuracy': acc,
        'balanced_accuracy': bal_acc,
        'precision': prec,
        'recall': rec,
        'f1_score': f1,
        'roc_auc': auc,
        'mcc': mcc,
        'confusion_matrix': cm.tolist()
    }

    print(f"Metrics for {target}:")
    print(f"Accuracy: {acc:.4f}, Balanced Acc: {bal_acc:.4f}, F1: {f1:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}, AUC: {auc:.4f}, MCC: {mcc:.4f}")

    # Plot confusion matrix
    plt.figure(figsize=(4,3))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"{target} Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_FOLDER, f"nn_cm_{target}.png"))
    plt.close()

# Save metrics
pd.DataFrame(results).T.to_csv(os.path.join(OUTPUT_FOLDER, f"{EXPERIMENT_NAME}_metrics_nn.csv"))
# Out:
# Training model for label: HBOND
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 71s 4ms/step - accuracy: 0.6904 - auc: 0.7485 - f1_score: 0.8434 - loss: 0.5901 - precision: 0.8508 - recall: 0.6973 - val_accuracy: 0.7869 - val_auc: 0.8755 - val_f1_score: 0.8421 - val_loss: 0.4512 - val_precision: 0.9093 - val_recall: 0.7854
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 75s 4ms/step - accuracy: 0.7788 - auc: 0.8617 - f1_score: 0.8425 - loss: 0.4637 - precision: 0.9021 - recall: 0.7809 - val_accuracy: 0.7964 - val_auc: 0.8864 - val_f1_score: 0.8421 - val_loss: 0.4251 - val_precision: 0.9143 - val_recall: 0.7945
# Epoch 3/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.7873 - auc: 0.8746 - f1_score: 0.8431 - loss: 0.4419 - precision: 0.9096 - recall: 0.7862 - val_accuracy: 0.8051 - val_auc: 0.8906 - val_f1_score: 0.8421 - val_loss: 0.4103 - val_precision: 0.9122 - val_recall: 0.8099
# Epoch 4/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.7913 - auc: 0.8803 - f1_score: 0.8428 - loss: 0.4324 - precision: 0.9130 - recall: 0.7886 - val_accuracy: 0.8031 - val_auc: 0.8938 - val_f1_score: 0.8421 - val_loss: 0.4078 - val_precision: 0.9171 - val_recall: 0.8017
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9516 - auc: 0.9888 - f1_score: 0.0482 - loss: 0.0893 - precision: 0.3365 - recall: 0.9980 - val_accuracy: 0.9521 - val_auc: 0.9889 - val_f1_score: 0.0467 - val_loss: 0.1234 - val_precision: 0.3321 - val_recall: 0.9967
# Epoch 9/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 4ms/step - accuracy: 0.9514 - auc: 0.9889 - f1_score: 0.0483 - loss: 0.0897 - precision: 0.3361 - recall: 0.9977 - val_accuracy: 0.9518 - val_auc: 0.9890 - val_f1_score: 0.0466 - val_loss: 0.1162 - val_precision: 0.3309 - val_recall: 0.9978
# Epoch 10/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9514 - auc: 0.9889 - f1_score: 0.0483 - loss: 0.0894 - precision: 0.3361 - recall: 0.9978 - val_accuracy: 0.9512 - val_auc: 0.9891 - val_f1_score: 0.0466 - val_loss: 0.1281 - val_precision: 0.3280 - val_recall: 0.9972
# Epoch 11/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9514 - auc: 0.9889 - f1_score: 0.0486 - loss: 0.0897 - precision: 0.3375 - recall: 0.9977 - val_accuracy: 0.9516 - val_auc: 0.9889 - val_f1_score: 0.0466 - val_loss: 0.1247 - val_precision: 0.3298 - val_recall: 0.9987
# Epoch 12/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.9515 - auc: 0.9893 - f1_score: 0.0478 - loss: 0.0884 - precision: 0.3338 - recall: 0.9973 - val_accuracy: 0.9520 - val_auc: 0.9891 - val_f1_score: 0.0467 - val_loss: 0.1201 - val_precision: 0.3316 - val_recall: 0.9965
# Epoch 13/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.9519 - auc: 0.9893 - f1_score: 0.0481 - loss: 0.0883 - precision: 0.3366 - recall: 0.9977 - val_accuracy: 0.9513 - val_auc: 0.9894 - val_f1_score: 0.0467 - val_loss: 0.1261 - val_precision: 0.3285 - val_recall: 0.9985
# Epoch 14/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.9521 - auc: 0.9895 - f1_score: 0.0485 - loss: 0.0875 - precision: 0.3396 - recall: 0.9976 - val_accuracy: 0.9508 - val_auc: 0.9893 - val_f1_score: 0.0467 - val_loss: 0.1324 - val_precision: 0.3264 - val_recall: 0.9983
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9525 - auc: 0.9892 - f1_score: 0.0450 - loss: 0.1136 - precision: 0.3262 - recall: 0.9967
# Test Loss: 0.1180
# Test Accuracy: 0.9509
# Test Precision: 0.3231
# test AUC: 0.9889
# Test Recall: 0.9961
# Test F1 Score: 0.0460
# Metrics for IONIC:
# Accuracy: 0.9509, Balanced Acc: 0.9729, F1: 0.7311, Precision: 0.6615, Recall: 0.9729, AUC: 0.9889, MCC: 0.5527
#
# Training model for label: PICATION
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 70s 4ms/step - accuracy: 0.8392 - auc: 0.9680 - f1_score: 0.0119 - loss: 0.2375 - precision: 0.0461 - recall: 0.9818 - val_accuracy: 0.9741 - val_auc: 0.9924 - val_f1_score: 0.0118 - val_loss: 0.1034 - val_precision: 0.1872 - val_recall: 1.0000
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 62s 4ms/step - accuracy: 0.9741 - auc: 0.9915 - f1_score: 0.0122 - loss: 0.0655 - precision: 0.1916 - recall: 0.9972 - val_accuracy: 0.9749 - val_auc: 0.9929 - val_f1_score: 0.0118 - val_loss: 0.0879 - val_precision: 0.1917 - val_recall: 0.9993
# Epoch 3/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 85s 5ms/step - accuracy: 0.9748 - auc: 0.9916 - f1_score: 0.0118 - loss: 0.0615 - precision: 0.1907 - recall: 0.9980 - val_accuracy: 0.9756 - val_auc: 0.9932 - val_f1_score: 0.0118 - val_loss: 0.0805 - val_precision: 0.1951 - val_recall: 0.9911
# Epoch 4/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.9748 - auc: 0.9927 - f1_score: 0.0118 - loss: 0.0588 - precision: 0.1896 - recall: 0.9969 - val_accuracy: 0.9747 - val_auc: 0.9932 - val_f1_score: 0.0119 - val_loss: 0.0862 - val_precision: 0.1907 - val_recall: 1.0000
# Epoch 5/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.9751 - auc: 0.9926 - f1_score: 0.0121 - loss: 0.0581 - precision: 0.1962 - recall: 0.9984 - val_accuracy: 0.9744 - val_auc: 0.9931 - val_f1_score: 0.0119 - val_loss: 0.0886 - val_precision: 0.1891 - val_recall: 1.0000
# Epoch 6/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9751 - auc: 0.9929 - f1_score: 0.0118 - loss: 0.0560 - precision: 0.1923 - recall: 0.9985 - val_accuracy: 0.9749 - val_auc: 0.9932 - val_f1_score: 0.0119 - val_loss: 0.0913 - val_precision: 0.1918 - val_recall: 0.9978
# Epoch 7/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 83s 4ms/step - accuracy: 0.9755 - auc: 0.9930 - f1_score: 0.0117 - loss: 0.0553 - precision: 0.1929 - recall: 0.9990 - val_accuracy: 0.9749 - val_auc: 0.9934 - val_f1_score: 0.0119 - val_loss: 0.0846 - val_precision: 0.1921 - val_recall: 0.9993
# Epoch 8/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.9755 - auc: 0.9932 - f1_score: 0.0118 - loss: 0.0556 - precision: 0.1937 - recall: 0.9980 - val_accuracy: 0.9754 - val_auc: 0.9935 - val_f1_score: 0.0119 - val_loss: 0.0771 - val_precision: 0.1949 - val_recall: 0.9970
# Epoch 9/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9754 - auc: 0.9929 - f1_score: 0.0119 - loss: 0.0553 - precision: 0.1938 - recall: 0.9977 - val_accuracy: 0.9753 - val_auc: 0.9934 - val_f1_score: 0.0119 - val_loss: 0.0817 - val_precision: 0.1937 - val_recall: 0.9963
# Epoch 10/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.9761 - auc: 0.9935 - f1_score: 0.0120 - loss: 0.0548 - precision: 0.1999 - recall: 0.9974 - val_accuracy: 0.9754 - val_auc: 0.9935 - val_f1_score: 0.0119 - val_loss: 0.0815 - val_precision: 0.1950 - val_recall: 0.9993
# Epoch 11/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.9757 - auc: 0.9932 - f1_score: 0.0121 - loss: 0.0564 - precision: 0.1973 - recall: 0.9977 - val_accuracy: 0.9751 - val_auc: 0.9933 - val_f1_score: 0.0119 - val_loss: 0.0873 - val_precision: 0.1931 - val_recall: 0.9970
# Epoch 12/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9763 - auc: 0.9934 - f1_score: 0.0120 - loss: 0.0543 - precision: 0.1995 - recall: 0.9983 - val_accuracy: 0.9756 - val_auc: 0.9935 - val_f1_score: 0.0119 - val_loss: 0.0792 - val_precision: 0.1960 - val_recall: 0.9978
# Epoch 13/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.9758 - auc: 0.9934 - f1_score: 0.0119 - loss: 0.0555 - precision: 0.1948 - recall: 0.9959 - val_accuracy: 0.9750 - val_auc: 0.9935 - val_f1_score: 0.0119 - val_loss: 0.0906 - val_precision: 0.1924 - val_recall: 0.9993
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.9746 - auc: 0.9926 - f1_score: 0.0126 - loss: 0.0797 - precision: 0.1981 - recall: 0.9918
# Test Loss: 0.0798
# Test Accuracy: 0.9747
# Test Precision: 0.2006
# test AUC: 0.9936
# Test Recall: 0.9937
# Test F1 Score: 0.0127
# Metrics for PICATION:
# Accuracy: 0.9747, Balanced Acc: 0.9841, F1: 0.6605, Precision: 0.6003, Recall: 0.9841, AUC: 0.9936, MCC: 0.4407
#
# Training model for label: PIHBOND
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.6733 - auc: 0.8715 - f1_score: 0.0025 - loss: 0.4672 - precision: 0.0037 - recall: 0.9102 - val_accuracy: 0.8371 - val_auc: 0.9316 - val_f1_score: 0.0022 - val_loss: 0.3852 - val_precision: 0.0061 - val_recall: 0.9146
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 78s 4ms/step - accuracy: 0.8455 - auc: 0.9435 - f1_score: 0.0025 - loss: 0.2959 - precision: 0.0075 - recall: 0.9299 - val_accuracy: 0.8552 - val_auc: 0.9354 - val_f1_score: 0.0022 - val_loss: 0.3439 - val_precision: 0.0067 - val_recall: 0.8943
# Epoch 3/20
# Epoch 12/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.9092 - auc: 0.9735 - f1_score: 0.0024 - loss: 0.1763 - precision: 0.0128 - recall: 0.9682 - val_accuracy: 0.9043 - val_auc: 0.9442 - val_f1_score: 0.0022 - val_loss: 0.2277 - val_precision: 0.0094 - val_recall: 0.8293
# Epoch 13/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.9088 - auc: 0.9745 - f1_score: 0.0025 - loss: 0.1693 - precision: 0.0131 - recall: 0.9675 - val_accuracy: 0.9080 - val_auc: 0.9448 - val_f1_score: 0.0022 - val_loss: 0.2192 - val_precision: 0.0091 - val_recall: 0.7724
# Epoch 14/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 67s 5ms/step - accuracy: 0.9081 - auc: 0.9730 - f1_score: 0.0026 - loss: 0.1731 - precision: 0.0135 - recall: 0.9741 - val_accuracy: 0.9177 - val_auc: 0.9456 - val_f1_score: 0.0022 - val_loss: 0.1929 - val_precision: 0.0099 - val_recall: 0.7520
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.9189 - auc: 0.9597 - f1_score: 0.0026 - loss: 0.1866 - precision: 0.0134 - recall: 0.8576
# Test Loss: 0.1901
# Test Accuracy: 0.9171
# Test Precision: 0.0131
# test AUC: 0.9563
# Test Recall: 0.8543
# Test F1 Score: 0.0026
# Metrics for PIHBOND:
# Accuracy: 0.9171, Balanced Acc: 0.8857, F1: 0.4912, Precision: 0.5065, Recall: 0.8857, AUC: 0.9565, MCC: 0.0998
#
# Training model for label: PIPISTACK
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9105 - auc: 0.9840 - f1_score: 0.0509 - loss: 0.1462 - precision: 0.3008 - recall: 0.9867 - val_accuracy: 0.9904 - val_auc: 0.9969 - val_f1_score: 0.0520 - val_loss: 0.0469 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.9904 - auc: 0.9965 - f1_score: 0.0506 - loss: 0.0291 - precision: 0.7289 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9972 - val_f1_score: 0.0528 - val_loss: 0.0429 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 3/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.9906 - auc: 0.9967 - f1_score: 0.0516 - loss: 0.0274 - precision: 0.7357 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9972 - val_f1_score: 0.0529 - val_loss: 0.0426 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 4/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 83s 5ms/step - accuracy: 0.9906 - auc: 0.9970 - f1_score: 0.0516 - loss: 0.0269 - precision: 0.7348 - recall: 0.9999 - val_accuracy: 0.9903 - val_auc: 0.9971 - val_f1_score: 0.0529 - val_loss: 0.0426 - val_precision: 0.7345 - val_recall: 1.0000
# Epoch 5/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 4ms/step - accuracy: 0.9906 - auc: 0.9970 - f1_score: 0.0518 - loss: 0.0266 - precision: 0.7352 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9972 - val_f1_score: 0.0529 - val_loss: 0.0452 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 6/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9904 - auc: 0.9970 - f1_score: 0.0525 - loss: 0.0270 - precision: 0.7331 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9973 - val_f1_score: 0.0529 - val_loss: 0.0424 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 7/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.9906 - auc: 0.9972 - f1_score: 0.0526 - loss: 0.0262 - precision: 0.7352 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9973 - val_f1_score: 0.0529 - val_loss: 0.0411 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 8/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 4ms/step - accuracy: 0.9905 - auc: 0.9972 - f1_score: 0.0524 - loss: 0.0264 - precision: 0.7322 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9973 - val_f1_score: 0.0529 - val_loss: 0.0402 - val_precision: 0.7347 - val_recall: 1.0000
# Epoch 9/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9906 - auc: 0.9973 - f1_score: 0.0529 - loss: 0.0259 - precision: 0.7352 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9973 - val_f1_score: 0.0529 - val_loss: 0.0420 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 10/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.9905 - auc: 0.9973 - f1_score: 0.0530 - loss: 0.0261 - precision: 0.7317 - recall: 1.0000 - val_accuracy: 0.9903 - val_auc: 0.9973 - val_f1_score: 0.0531 - val_loss: 0.0417 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 11/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9904 - auc: 0.9973 - f1_score: 0.0535 - loss: 0.0264 - precision: 0.7310 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9974 - val_f1_score: 0.0531 - val_loss: 0.0429 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 12/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9905 - auc: 0.9973 - f1_score: 0.0536 - loss: 0.0260 - precision: 0.7326 - recall: 0.9996 - val_accuracy: 0.9904 - val_auc: 0.9974 - val_f1_score: 0.0531 - val_loss: 0.0412 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 13/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.9906 - auc: 0.9975 - f1_score: 0.0544 - loss: 0.0253 - precision: 0.7364 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9974 - val_f1_score: 0.0534 - val_loss: 0.0394 - val_precision: 0.7361 - val_recall: 0.9998
# Epoch 14/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.9907 - auc: 0.9975 - f1_score: 0.0542 - loss: 0.0253 - precision: 0.7361 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9975 - val_f1_score: 0.0533 - val_loss: 0.0396 - val_precision: 0.7347 - val_recall: 1.0000
# Epoch 15/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.9908 - auc: 0.9975 - f1_score: 0.0541 - loss: 0.0249 - precision: 0.7371 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9975 - val_f1_score: 0.0531 - val_loss: 0.0402 - val_precision: 0.7349 - val_recall: 1.0000
# Epoch 16/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 5ms/step - accuracy: 0.9905 - auc: 0.9976 - f1_score: 0.0542 - loss: 0.0252 - precision: 0.7315 - recall: 0.9999 - val_accuracy: 0.9904 - val_auc: 0.9971 - val_f1_score: 0.0538 - val_loss: 0.0450 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 17/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.9907 - auc: 0.9976 - f1_score: 0.0552 - loss: 0.0249 - precision: 0.7379 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9974 - val_f1_score: 0.0538 - val_loss: 0.0425 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 18/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.9906 - auc: 0.9976 - f1_score: 0.0548 - loss: 0.0248 - precision: 0.7344 - recall: 0.9998 - val_accuracy: 0.9904 - val_auc: 0.9975 - val_f1_score: 0.0534 - val_loss: 0.0395 - val_precision: 0.7356 - val_recall: 0.9998
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.9909 - auc: 0.9975 - f1_score: 0.0529 - loss: 0.0376 - precision: 0.7419 - recall: 0.9996
# Test Loss: 0.0389
# Test Accuracy: 0.9906
# Test Precision: 0.7463
# test AUC: 0.9974
# Test Recall: 0.9995
# Test F1 Score: 0.0550
# Metrics for PIPISTACK:
# Accuracy: 0.9906, Balanced Acc: 0.9949, F1: 0.9248, Precision: 0.8731, Recall: 0.9949, AUC: 0.9976, MCC: 0.8595
#
# Training model for label: SSBOND
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 75s 5ms/step - accuracy: 0.8401 - auc: 0.9817 - f1_score: 0.0030 - loss: 0.1907 - precision: 0.0153 - recall: 0.9806 - val_accuracy: 0.9995 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0059 - val_precision: 0.7532 - val_recall: 1.0000
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.9992 - auc: 0.9995 - f1_score: 0.0030 - loss: 0.0047 - precision: 0.6452 - recall: 0.9999 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0043 - val_precision: 0.7832 - val_recall: 1.0000
# Epoch 3/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.9993 - auc: 0.9995 - f1_score: 0.0030 - loss: 0.0036 - precision: 0.6835 - recall: 0.9998 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0035 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 4/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 84s 5ms/step - accuracy: 0.9994 - auc: 0.9996 - f1_score: 0.0030 - loss: 0.0030 - precision: 0.7038 - recall: 0.9999 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0042 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 5/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.9994 - auc: 0.9984 - f1_score: 0.0029 - loss: 0.0032 - precision: 0.6977 - recall: 0.9986 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0043 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 6/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.9994 - auc: 0.9974 - f1_score: 0.0031 - loss: 0.0029 - precision: 0.7077 - recall: 0.9977 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0027 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 7/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 84s 5ms/step - accuracy: 0.9993 - auc: 0.9997 - f1_score: 0.0030 - loss: 0.0029 - precision: 0.6916 - recall: 0.9999 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0035 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 8/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 5ms/step - accuracy: 0.9993 - auc: 0.9979 - f1_score: 0.0030 - loss: 0.0032 - precision: 0.6914 - recall: 0.9981 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0031 - val_loss: 0.0038 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 9/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.9993 - auc: 0.9996 - f1_score: 0.0031 - loss: 0.0031 - precision: 0.6815 - recall: 0.9999 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0032 - val_loss: 0.0035 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 10/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.9994 - auc: 0.9995 - f1_score: 0.0032 - loss: 0.0028 - precision: 0.7029 - recall: 0.9997 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0032 - val_loss: 0.0034 - val_precision: 0.7849 - val_recall: 1.0000
# Epoch 11/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.9993 - auc: 0.9994 - f1_score: 0.0032 - loss: 0.0029 - precision: 0.6924 - recall: 0.9996 - val_accuracy: 0.9996 - val_auc: 0.9998 - val_f1_score: 0.0032 - val_loss: 0.0044 - val_precision: 0.7849 - val_recall: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.9993 - auc: 0.9986 - f1_score: 0.0023 - loss: 0.0039 - precision: 0.6282 - recall: 0.9988
# Test Loss: 0.0043
# Test Accuracy: 0.9993
# Test Precision: 0.6054
# test AUC: 0.9997
# Test Recall: 1.0000
# Test F1 Score: 0.0022
# Metrics for SSBOND:
# Accuracy: 0.9993, Balanced Acc: 0.9996, F1: 0.8769, Precision: 0.8027, Recall: 0.9996, AUC: 0.9998, MCC: 0.7778
#
# Training model for label: VDW
# Epoch 1/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.5830 - auc: 0.6159 - f1_score: 0.6726 - loss: 0.6826 - precision: 0.5907 - recall: 0.5857 - val_accuracy: 0.6562 - val_auc: 0.7266 - val_f1_score: 0.6736 - val_loss: 0.6064 - val_precision: 0.6789 - val_recall: 0.6130
# Epoch 2/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 64s 4ms/step - accuracy: 0.6490 - auc: 0.7123 - f1_score: 0.6725 - loss: 0.6180 - precision: 0.6686 - recall: 0.6090 - val_accuracy: 0.6618 - val_auc: 0.7346 - val_f1_score: 0.6736 - val_loss: 0.5987 - val_precision: 0.6938 - val_recall: 0.5978
# Epoch 3/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 63s 4ms/step - accuracy: 0.6559 - auc: 0.7235 - f1_score: 0.6730 - loss: 0.6081 - precision: 0.6765 - recall: 0.6162 - val_accuracy: 0.6646 - val_auc: 0.7389 - val_f1_score: 0.6736 - val_loss: 0.5937 - val_precision: 0.6938 - val_recall: 0.6078
# Epoch 4/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 85s 5ms/step - accuracy: 0.6600 - auc: 0.7292 - f1_score: 0.6721 - loss: 0.6031 - precision: 0.6799 - recall: 0.6205 - val_accuracy: 0.6662 - val_auc: 0.7413 - val_f1_score: 0.6736 - val_loss: 0.5911 - val_precision: 0.6968 - val_recall: 0.6068
# Epoch 5/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 5ms/step - accuracy: 0.6622 - auc: 0.7325 - f1_score: 0.6727 - loss: 0.5997 - precision: 0.6824 - recall: 0.6239 - val_accuracy: 0.6668 - val_auc: 0.7425 - val_f1_score: 0.6736 - val_loss: 0.5895 - val_precision: 0.6910 - val_recall: 0.6224
# Epoch 6/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 4ms/step - accuracy: 0.6655 - auc: 0.7368 - f1_score: 0.6733 - loss: 0.5961 - precision: 0.6868 - recall: 0.6269 - val_accuracy: 0.6699 - val_auc: 0.7460 - val_f1_score: 0.6736 - val_loss: 0.5873 - val_precision: 0.7045 - val_recall: 0.6030
# Epoch 7/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.6675 - auc: 0.7396 - f1_score: 0.6726 - loss: 0.5931 - precision: 0.6895 - recall: 0.6254 - val_accuracy: 0.6702 - val_auc: 0.7469 - val_f1_score: 0.6736 - val_loss: 0.5859 - val_precision: 0.7018 - val_recall: 0.6096
# Epoch 8/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 84s 5ms/step - accuracy: 0.6696 - auc: 0.7417 - f1_score: 0.6723 - loss: 0.5911 - precision: 0.6914 - recall: 0.6276 - val_accuracy: 0.6715 - val_auc: 0.7479 - val_f1_score: 0.6736 - val_loss: 0.5847 - val_precision: 0.6972 - val_recall: 0.6243
# Epoch 9/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.6693 - auc: 0.7420 - f1_score: 0.6725 - loss: 0.5910 - precision: 0.6906 - recall: 0.6290 - val_accuracy: 0.6733 - val_auc: 0.7504 - val_f1_score: 0.6736 - val_loss: 0.5825 - val_precision: 0.7118 - val_recall: 0.5997
# Epoch 10/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.6708 - auc: 0.7441 - f1_score: 0.6726 - loss: 0.5885 - precision: 0.6928 - recall: 0.6293 - val_accuracy: 0.6735 - val_auc: 0.7507 - val_f1_score: 0.6736 - val_loss: 0.5819 - val_precision: 0.7053 - val_recall: 0.6135
# Epoch 11/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.6724 - auc: 0.7457 - f1_score: 0.6725 - loss: 0.5872 - precision: 0.6959 - recall: 0.6276 - val_accuracy: 0.6733 - val_auc: 0.7510 - val_f1_score: 0.6736 - val_loss: 0.5822 - val_precision: 0.7104 - val_recall: 0.6023
# Epoch 12/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 4ms/step - accuracy: 0.6737 - auc: 0.7469 - f1_score: 0.6731 - loss: 0.5861 - precision: 0.6975 - recall: 0.6301 - val_accuracy: 0.6742 - val_auc: 0.7513 - val_f1_score: 0.6736 - val_loss: 0.5814 - val_precision: 0.7125 - val_recall: 0.6010
# Epoch 13/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 68s 5ms/step - accuracy: 0.6736 - auc: 0.7469 - f1_score: 0.6732 - loss: 0.5861 - precision: 0.6966 - recall: 0.6318 - val_accuracy: 0.6752 - val_auc: 0.7531 - val_f1_score: 0.6736 - val_loss: 0.5798 - val_precision: 0.7064 - val_recall: 0.6167
# Epoch 14/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.6738 - auc: 0.7479 - f1_score: 0.6726 - loss: 0.5851 - precision: 0.6975 - recall: 0.6289 - val_accuracy: 0.6762 - val_auc: 0.7534 - val_f1_score: 0.6736 - val_loss: 0.5790 - val_precision: 0.6993 - val_recall: 0.6359
# Epoch 15/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 80s 5ms/step - accuracy: 0.6740 - auc: 0.7479 - f1_score: 0.6733 - loss: 0.5851 - precision: 0.6975 - recall: 0.6317 - val_accuracy: 0.6765 - val_auc: 0.7539 - val_f1_score: 0.6736 - val_loss: 0.5785 - val_precision: 0.7059 - val_recall: 0.6223
# Epoch 16/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.6752 - auc: 0.7498 - f1_score: 0.6730 - loss: 0.5833 - precision: 0.6987 - recall: 0.6321 - val_accuracy: 0.6775 - val_auc: 0.7544 - val_f1_score: 0.6736 - val_loss: 0.5786 - val_precision: 0.7143 - val_recall: 0.6083
# Epoch 17/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 66s 5ms/step - accuracy: 0.6764 - auc: 0.7506 - f1_score: 0.6724 - loss: 0.5828 - precision: 0.7004 - recall: 0.6312 - val_accuracy: 0.6781 - val_auc: 0.7552 - val_f1_score: 0.6736 - val_loss: 0.5776 - val_precision: 0.7106 - val_recall: 0.6178
# Epoch 18/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 65s 5ms/step - accuracy: 0.6766 - auc: 0.7504 - f1_score: 0.6723 - loss: 0.5826 - precision: 0.7008 - recall: 0.6305 - val_accuracy: 0.6790 - val_auc: 0.7560 - val_f1_score: 0.6736 - val_loss: 0.5762 - val_precision: 0.7070 - val_recall: 0.6285
# Epoch 19/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.6779 - auc: 0.7521 - f1_score: 0.6727 - loss: 0.5811 - precision: 0.7020 - recall: 0.6332 - val_accuracy: 0.6770 - val_auc: 0.7540 - val_f1_score: 0.6736 - val_loss: 0.5778 - val_precision: 0.7090 - val_recall: 0.6176
# Epoch 20/20
# 13995/13995 ━━━━━━━━━━━━━━━━━━━━ 82s 4ms/step - accuracy: 0.6778 - auc: 0.7519 - f1_score: 0.6728 - loss: 0.5812 - precision: 0.7030 - recall: 0.6311 - val_accuracy: 0.6782 - val_auc: 0.7556 - val_f1_score: 0.6736 - val_loss: 0.5768 - val_precision: 0.7101 - val_recall: 0.6192
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4252/4252 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.6811 - auc: 0.7576 - f1_score: 0.6738 - loss: 0.5747 - precision: 0.7120 - recall: 0.6253
# Test Loss: 0.5735
# Test Accuracy: 0.6816
# Test Precision: 0.7132
# test AUC: 0.7589
# Test Recall: 0.6269
# Test F1 Score: 0.6748
# Metrics for VDW:
# Accuracy: 0.6816, Balanced Acc: 0.6827, F1: 0.6810, Precision: 0.6846, Recall: 0.6827, AUC: 0.7589, MCC: 0.3673
